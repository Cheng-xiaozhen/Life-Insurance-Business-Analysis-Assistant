# %%
from life_insurance_business_analysis_assistant.agent.graph import build_graph
from IPython.display import Image, display
display(Image(build_graph().get_graph(xray=True).draw_mermaid_png()))
